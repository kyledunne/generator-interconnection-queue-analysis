# %%
import pandas as pd
import numpy as np
# !pip install openpyxl
# Out:
# ...
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...

# %%
tva = pd.read_excel('data/domsc.xlsx')
tva.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63 entries, 0 to 62
# Data columns (total 16 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Queue Position ID                          63 non-null     int64
#  1   Request #                                  63 non-null     int64
#  2   Date of Completed Application
# and Deposit  63 non-null     datetime64[ns]
#  3   Net Summer/ Winter
# (MW)                    63 non-null     float64
#  4   Location (County, State)                   63 non-null     object
#  5   DESC Transmission Line or Substation       63 non-null     object
#  6   Requested In-Service Date                  63 non-null     datetime64[ns]
#  7   Revised Requested In-Service
# Date          2 non-null      datetime64[ns]
#  8   Requested Interconnection Service          63 non-null     object
# ...

# %%
tva.head()
# Out:
#    Queue Position ID    Request # Date of Completed Application\nand Deposit  \
# 0                 41  20151028001                                 2015-11-18
# 1                 42  20171013002                                 2017-10-13
# 2                 43  20171018008                                 2017-10-18
# 3                 44  20171018010                                 2017-10-18
# 4                 45  20171018005                                 2017-10-18
#
#    Net Summer/ Winter\n(MW) Location (County, State)  \
# 0                     113.4           Orangeburg, SC
# 1                     151.2                Aiken, SC
# 2                     100.0           Orangeburg, SC
# 3                     100.0           Orangeburg, SC
# 4                     100.0             Richland, SC
#
#           DESC Transmission Line or Substation Requested In-Service Date  \
# 0                Cope - Orangeburg East 230 kV                2019-06-01
# ...
